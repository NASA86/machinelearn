# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
datasets=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
datasets
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=datasets[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=datasets[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features': [None,'sqrt','log2'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
#print grid cv results
re=grid.cv_results_
#print(re)
grid_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_pred)
print("R2 value for best parameters:",format(grid.best_params_),r_score)
# Out:
# R2 value for best parameters: {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100} 0.8726413267628842

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.060039      0.002475         0.006782    7.465313e-04
# 1        0.503453      0.004696         0.017952    6.311281e-04
# 2        0.044879      0.000632         0.006383    4.888892e-04
# 3        0.399332      0.005374         0.017555    7.960642e-04
# 4        0.044481      0.001197         0.005186    3.984690e-04
# 5        0.387563      0.003432         0.017753    7.463785e-04
# 6        0.174133      0.004661         0.006384    7.984638e-04
# 7        1.704641      0.018854         0.017355    7.975820e-04
# 8        0.101328      0.001493         0.005785    3.990412e-04
# 9        1.040017      0.020472         0.017953    1.092623e-03
# 10       0.108110      0.003254         0.005386    4.889477e-04
# 11       1.039420      0.016753         0.017354    1.353197e-03
# 12       0.053057      0.000399         0.006782    1.595831e-03
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
future_pred=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future prediction:",format(future_pred))
# Out:
# Future prediction: [42441.1113951]
# C:\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
